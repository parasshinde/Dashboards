# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Data\Desktop\Data\Paras Workspace\programes\Power BI\Web Scraping csv\stagging_survey_data.csv")
df

# %%
df.drop(columns=["Check"], axis=1, inplace=True)
df

# %%
df.info()
df.describe()

# %%
df['WorkExp'].unique()

# %%
df['WorkExp'] = df['WorkExp'].replace(to_replace=np.nan, value= 0)
df['WorkExp']

# %%
df.isnull().sum()

# %%
df['SurveyEase'] = df['SurveyEase'].replace(to_replace=np.nan, value='Other')
df

# %%
#removing columns which passes the threshold of 50 null values
df.drop(columns= ['TechDoc','PlatformHaveWorkedWith','EmbeddedHaveWorkedWith','AISearchDevHaveWorkedWith','AIToolInterested in Using','AIAcc','AIComplex', 'AIEthics','AINextNo change'], axis=1, inplace=True)
df

# %%
array_1 = df['RemoteWork'].unique()
print(array_1)
type(array_1[1]) # nan is float that is np.nan

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'YearsCode', 'YearsCodePro', 'DevType', 'Country',
#        'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'WebframeHaveWorkedWith',
#        'ToolsTechHaveWorkedWith', 'NEWCollabToolsHaveWorkedWith', 'NEWSOSites',
#        'SOVisitFreq', 'AIThreat', 'WorkExp', 'Industry', 'SurveyLength',
#        'SurveyEase'],
#       dtype='object')

# %%
type(df['YearsCode'][0])
# Out:
# str

# %%
df.set_index(df['ResponseId'])
# Out:
#             ResponseId                      MainBranch                 Age  \
# ResponseId
# 1                    1  I am a developer by profession  Under 18 years old
# 2                    2  I am a developer by profession     35-44 years old
# 3                    3  I am a developer by profession     45-54 years old
# 4                    4           I am learning to code     18-24 years old
# 5                    5  I am a developer by profession     18-24 years old
# ...                ...                             ...                 ...
# 196                196  I am a developer by profession     25-34 years old
# 197                197  I am a developer by profession     35-44 years old
# 198                198  I am a developer by profession     25-34 years old
# 199                199  I am a developer by profession     35-44 years old
# 200                200  I am a developer by profession     45-54 years old
#
# ...

# %%
df.to_csv(r'C:\Data\Desktop\Data\Paras Workspace\programes\Power BI\Web Scraping csv\stagging_survey_data_1.csv', index=False)
